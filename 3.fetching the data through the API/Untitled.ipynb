# %%
import pandas as pd
import requests

# %%
response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=3ec99928c5d65586858a42b709e02e59&language=en-US&page=1")

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/gNBCvtYyGPbjPCT1k3MvJuNuXR6.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 19404,
#    'original_language': 'hi',
#    'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#    'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#    'popularity': 16.791,
#    'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#    'release_date': '1995-10-20',
#    'title': 'Dilwale Dulhania Le Jayenge',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 3058},
#   {'adult': False,
#    'backdrop_path': '/iNh3BivHyg5sQRPP1KOkzguEX0H.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/gNBCvtYyGPbjPCT1k3MvJuNuXR6.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 19404,
#   'original_language': 'hi',
#   'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#   'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#   'popularity': 16.791,
#   'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#   'release_date': '1995-10-20',
#   'title': 'Dilwale Dulhania Le Jayenge',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 3058},
#  {'adult': False,
#   'backdrop_path': '/iNh3BivHyg5sQRPP1KOkzguEX0H.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path            genre_ids      id  \
# 0   False  /gNBCvtYyGPbjPCT1k3MvJuNuXR6.jpg      [35, 18, 10749]   19404
# 1   False  /iNh3BivHyg5sQRPP1KOkzguEX0H.jpg             [18, 80]     278
# 2   False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg             [18, 80]     238
# 3   False  /jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg              [10749]  724089
# 4   False  /fQq1FWp1rC89xDrRMuyFJdFUdMd.jpg          [10749, 35]  761053
# 5   False  /w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg              [10749]  696374
# 6   False  /loRmRzQXZeqG78TqZuyvSlEQfZb.jpg      [18, 36, 10752]     424
# 7   False  /lQAe1hfWYDdYypRVdzTbdg6JYWP.jpg                 [18]  526702
# 8   False  /poec6RqOKY9iSiIUmfyfPfiLtvB.jpg             [18, 80]     240
# 9   False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg      [10749, 16, 18]  372058
# 10  False  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg      [16, 10751, 14]     129
# 11  False   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg         [35, 53, 18]  496243
# ...

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df
# Out:
#         id                            title  \
# 0    19404      Dilwale Dulhania Le Jayenge
# 1      278         The Shawshank Redemption
# 2      238                    The Godfather
# 3   724089        Gabriel's Inferno Part II
# 4   761053       Gabriel's Inferno Part III
# 5   696374                Gabriel's Inferno
# 6      424                 Schindler's List
# 7   526702                     Black Beauty
# 8      240           The Godfather: Part II
# 9   372058                       Your Name.
# 10     129                    Spirited Away
# 11  496243                         Parasite
# 12  255709                             Hope
# 13  592350  My Hero Academia: Heroes Rising
# 14     497                   The Green Mile
# 15     389                     12 Angry Men
# 16   40096                     A Dog's Will
# 17     680                     Pulp Fiction
# 18  441130                      Wolfwalkers
# 19     155                  The Dark Knight
#
# ...

# %%
df1=pd.DataFrame() # empty dataframe

# %%
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=3ec99928c5d65586858a42b709e02e59&language=en-US&page={}".format(i))
    temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df1=df1.append(temp_df,ignore_index=True)

# %%
df1
# Out:
#           id                          title  \
# 0      19404    Dilwale Dulhania Le Jayenge
# 1        278       The Shawshank Redemption
# 2        238                  The Godfather
# 3     724089      Gabriel's Inferno Part II
# 4     761053     Gabriel's Inferno Part III
# ...      ...                            ...
# 8555   44912                  Green Lantern
# 8556    2395   Astérix at the Olympic Games
# 8557  560362                    Rattlesnake
# 8558   10167                 Half Past Dead
# 8559   57089  Hoodwinked Too! Hood VS. Evil
#
#                                                overview release_date  \
# 0     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 3     Professor Gabriel Emerson finally learns the t...   2020-07-31
# 4     The final part of the film adaption of the ero...   2020-11-19
# ...
